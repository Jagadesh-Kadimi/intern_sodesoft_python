# %%
import random
class passwordgenerator:
    def __init__(self,length):
        self.length=length
    def generate(self):
        password=""
        for i in range(self.length):
            password+=chr(random.randint(33,126))
        return password


def main():
  length=int(input("enter length of password:"))
  passgen=passwordgenerator(length)
  print(passgen.generate())
if __name__=="__main__":
  main()
# Out:
# enter length of password90
# FQSJ]M+Cb6w9+D.Z5W2c=$]f7Rw?'5C{t7(Rr2V`zZ,o+P)g?~=Fm}SHmNUBeQ%n}+h##21YPR<?-.ZNVL,RSN;)u>
